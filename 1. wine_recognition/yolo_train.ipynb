# %%
from glob import glob

img_list = glob('/home/jovyan/dataset/yolo/images/*.jpg')
img_list += glob('/home/jovyan/dataset/yolo/images/*.JPG')
img_list += glob('/home/jovyan/dataset2/yolo/images/*.jpg')
img_list += glob('/home/jovyan/dataset2/yolo/images/*.JPG')
print(len(img_list))
# Out:
# 528

# %%
k_fold = 5
total_size = len(img_list)
fraction = 1/k_fold
seg = int(total_size * fraction)

for i in range(k_fold):
    trll = 0
    trlr = i*seg
    vall = trlr
    valr = i * seg + seg
    trrl = valr
    trrr = total_size
    
    train_left_indices = list(img_list[trll: trlr])
    train_right_indices = list(img_list[trrl: trrr])
    train_indices = train_left_indices + train_right_indices
    val_indices = list(img_list[vall: valr])
    
    with open('/home/jovyan/data_total/yolo/train' + str(i) + '.txt', 'w') as f:
        f.write('\n'.join(train_indices) + '\n')
    
    with open('/home/jovyan/data_total/yolo/val' + str(i) + '.txt', 'w') as f:
        f.write('\n'.join(val_indices) + '\n')

# %%
import yaml

for i in range(k_fold):
    
    with open('/home/jovyan/data_total/yolo/data'+str(i)+'.yaml', 'r') as f:
        data = yaml.load(f)
    
    print(data)
# Out:
# {'names': ['label'], 'nc': 1, 'train': '/home/jovyan/data_total/yolo/train0.txt', 'val': '/home/jovyan/data_total/yolo/val0.txt'}
# {'names': ['label'], 'nc': 1, 'train': '/home/jovyan/data_total/yolo/train1.txt', 'val': '/home/jovyan/data_total/yolo/val1.txt'}
# {'names': ['label'], 'nc': 1, 'train': '/home/jovyan/data_total/yolo/train2.txt', 'val': '/home/jovyan/data_total/yolo/val2.txt'}
# {'names': ['label'], 'nc': 1, 'train': '/home/jovyan/data_total/yolo/train3.txt', 'val': '/home/jovyan/data_total/yolo/val3.txt'}
# {'names': ['label'], 'nc': 1, 'train': '/home/jovyan/data_total/yolo/train4.txt', 'val': '/home/jovyan/data_total/yolo/val4.txt'}
# /home/haiqv/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
# !python /home/jovyan/yolov5/train.py --img 1024 --batch 32 --epochs 300 --data /home/jovyan/data_total/yolo/data0.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# Traceback (most recent call last):
#   File "/home/jovyan/yolov5/train.py", line 30, in <module>
#     import val  # for end-of-epoch mAP
#   File "/home/jovyan/yolov5/val.py", line 21, in <module>
#     from models.experimental import attempt_load
#   File "/home/jovyan/yolov5/models/experimental.py", line 7, in <module>
#     from models.common import Conv, DWConv
#   File "/home/jovyan/yolov5/models/common.py", line 17, in <module>
#     from utils.datasets import exif_transpose, letterbox
#   File "/home/jovyan/yolov5/utils/datasets.py", line 16, in <module>
#     import cv2
#   File "/home/haiqv/anaconda3/lib/python3.7/site-packages/cv2/__init__.py", line 5, in <module>
#     from .cv2 import *
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory

# %%
# !python /home/jovyan/yolov5/train.py --img 1024 --batch 32 --epochs 150 --data /home/jovyan/data_total/yolo/data1.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/home/jovyan/data_total/yolo/data1.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=32, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=gun_yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-350-gf409d8e torch 1.9.0 CUDA:0 (A100-SXM4-40GB, 40537.1875MB)
#
# ...

# %%
# !python /home/jovyan/yolov5/train.py --img 1024 --batch 32 --epochs 150 --data /home/jovyan/data_total/yolo/data2.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/home/jovyan/data_total/yolo/data2.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=32, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=gun_yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-350-gf409d8e torch 1.9.0 CUDA:0 (A100-SXM4-40GB, 40537.1875MB)
#
# ...

# %%
# !python /home/jovyan/yolov5/train.py --img 1024 --batch 32 --epochs 150 --data /home/jovyan/data_total/yolo/data3.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/home/jovyan/data_total/yolo/data3.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=32, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=gun_yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-350-gf409d8e torch 1.9.0 CUDA:0 (A100-SXM4-40GB, 40537.1875MB)
#
# ...

# %%
# !python /home/jovyan/yolov5/train.py --img 1024 --batch 32 --epochs 150 --data /home/jovyan/data_total/yolo/data4.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/home/jovyan/data_total/yolo/data4.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=32, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=gun_yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-350-gf409d8e torch 1.9.0 CUDA:0 (A100-SXM4-40GB, 40537.1875MB)
#
# ...

# %%
from sklearn.model_selection import train_test_split
train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)
print(len(train_img_list), len(val_img_list))
# Out:
# 422 106

# %%
with open('/home/jovyan/data_total/yolo/train_total.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open('/home/jovyan/data_total/yolo/val_total.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
# !python /home/jovyan/yolov5/train.py --img 1024 --batch 32 --epochs 200 --data /home/jovyan/data_total/yolo/data_total.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/home/jovyan/data_total/yolo/data_total.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=200, batch_size=32, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=gun_yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-350-gf409d8e torch 1.9.0 CUDA:0 (A100-SXM4-40GB, 40537.1875MB)
#
# ...

# %%
# !python /home/jovyan/yolov5/detect.py --weights /home/jovyan/runs/train/gun_yolov5s_results30/weights/best.pt --img 1024 --conf 0.8 --source "dataset/yolo/images" --save-crop --name "IMG"
# Out:
# detect: weights=['/home/jovyan/runs/train/gun_yolov5s_results30/weights/best.pt'], source=dataset/yolo/images, imgsz=1024, conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=IMG, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# requirements: /home/jovyan/requirements.txt not found, check failed.
# YOLOv5 🚀 v5.0-350-gf409d8e torch 1.9.0 CUDA:0 (A100-SXM4-40GB, 40537.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/349 /home/jovyan/dataset/yolo/images/20210610_162501.jpg: 1024x1024 2 labels, Done. (0.009s)
# image 2/349 /home/jovyan/dataset/yolo/images/20210610_162505.jpg: 1024x1024 2 labels, Done. (0.009s)
# ...

# %%
# !python /home/jovyan/yolov5/detect.py --weights /home/jovyan/runs/train/gun_yolov5s_results30/weights/best.pt --img 1024 --conf 0.8 --source "dataset2/yolo/images" --save-crop --name "IMG"
# Out:
# detect: weights=['/home/jovyan/runs/train/gun_yolov5s_results30/weights/best.pt'], source=dataset2/yolo/images, imgsz=1024, conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=IMG, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# requirements: /home/jovyan/requirements.txt not found, check failed.
# YOLOv5 🚀 v5.0-350-gf409d8e torch 1.9.0 CUDA:0 (A100-SXM4-40GB, 40537.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/179 /home/jovyan/dataset2/yolo/images/20210908_153759.jpg: 1024x1024 4 labels, Done. (0.009s)
# image 2/179 /home/jovyan/dataset2/yolo/images/20210908_153815.jpg: 1024x1024 4 labels, Done. (0.009s)
# image 3/179 /home/jovyan/dataset2/yolo/images/20210908_153820.jpg: 1024x1024 Done. (0.009s)
# ...

# %%
import os
import zipfile
 
new_zips= zipfile.ZipFile('runs/detect/IMG/crops/label.zip', 'w')
 
for folder, subfolders, files in os.walk('runs/detect/IMG/crops/label'):
 
    for file in files:
        new_zips.write(os.path.join(folder, file), os.path.relpath(os.path.join(folder,file), 'runs/detect/IMG/crops/label'), compress_type = zipfile.ZIP_DEFLATED)
        
new_zips.close()

# %%
/home/jovyan/data_total/yolo/train
